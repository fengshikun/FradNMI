# %%
import altair as alt
import copy
import pandas as pd


log_dir = '/home/fengshikun/Pretraining-Denoising/log/time_step_2'
file_name = 'data_0.csv'
file_dir = f'{log_dir}/{file_name}'

def read_energy_csv(log_dir, idx=0):
    energy_step = None
    file_names = [f'data_{idx}.csv', f'data_rdkit_opt_True_{idx}.csv', f'data_rdkit_opt_False_{idx}.csv', f'data_{idx}_add_noise.csv']
    for i, f in enumerate(file_names):
        energy_lst = pd.read_csv(f'{log_dir}/{f}')
        energy_lst.rename(columns = {'#"Step"':'Step'}, inplace = True)
        energy_lst.rename(columns = {'Potential Energy (kJ/mole)': f'energy_{i}'}, inplace = True)
        if energy_step is None:
            energy_step = energy_lst[['Step', f'energy_{i}']]
        else:
            energy_step[f'energy_{i}'] = energy_lst[f'energy_{i}']
    return energy_step

energy_step = read_energy_csv(log_dir)
# energy_step
# alt.Chart(energy_step).mark_line(point=True,interpolate="natural").encode(
#     alt.X('Step:Q'
#     ),
#     alt.Y('Potential Energy (kJ/mole):Q'
#     )
# ).interactive()

# df_long = pd.melt(energy_step, id_vars='Step', var_name='y_values')


# alt.Chart(df_long).mark_line(point=True,interpolate="natural").encode(
#     x=alt.X('Step', title='Steps'),
#     y=alt.Y('y_values', title='Energy'),
#     color=alt.Color('y_values', title='Curve', scale=alt.Scale(scheme='category10')),
#     strokeDash=alt.StrokeDash('y_values', title='energy', legend=None, 
#                               scale=alt.Scale(domain=['energy_0', 'energy_1', 'energy_2']))
# ).properties(title='Energy per Steps').interactive()

alt.Chart(energy_step).transform_fold(['energy_0', 'energy_1', 'energy_2', 'energy_3']).mark_line().encode(
    x='Step:Q',
    y='value:Q',
    color='key:N'
).interactive()
# Out:
# /opt/conda/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
energy_step = read_energy_csv(log_dir, idx=1)
alt.Chart(energy_step).transform_fold(['energy_0', 'energy_1', 'energy_2', 'energy_3']).mark_line().encode(
    x='Step:Q',
    y='value:Q',
    color='key:N'
).interactive()
# Out:
# /opt/conda/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
energy_step = read_energy_csv(log_dir, idx=2)
alt.Chart(energy_step).transform_fold(['energy_0', 'energy_1', 'energy_2', 'energy_3']).mark_line().encode(
    x='Step:Q',
    y='value:Q',
    color='key:N'
).interactive()
# Out:
# /opt/conda/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
energy_step = read_energy_csv(log_dir, idx=3)
alt.Chart(energy_step).transform_fold(['energy_0', 'energy_1', 'energy_2']).mark_line().encode(
    x='Step:Q',
    y='value:Q',
    color='key:N'
).interactive()
# Out:
# /opt/conda/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
energy_step = read_energy_csv(log_dir, idx=4)
alt.Chart(energy_step).transform_fold(['energy_0', 'energy_1', 'energy_2']).mark_line().encode(
    x='Step:Q',
    y='value:Q',
    color='key:N'
).interactive()
# Out:
# /opt/conda/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
energy_step
# Out:
#      Step    energy_0    energy_1    energy_2
# 0       1  435.962041  455.162670  478.741362
# 1       2  427.702811  449.765726  466.139103
# 2       3  430.258180  448.292626  461.405808
# 3       4  438.919508  449.935821  463.278753
# 4       5  442.349584  451.742674  464.825950
# ..    ...         ...         ...         ...
# 995   996  518.507208  509.417320  512.334839
# 996   997  521.852380  508.811388  515.345107
# 997   998  529.577373  500.996229  516.312396
# 998   999  541.448689  495.029623  516.202184
# 999  1000  548.524118  497.572343  514.358273
#
# [1000 rows x 4 columns]

# %%
import altair as alt
import copy
import pandas as pd


log_dir = '/home/fengshikun/Pretraining-Denoising/log_s'
file_name = 'data_0.csv'
file_dir = f'{log_dir}/{file_name}'

def read_energy_csv(log_dir, idx=0):
    file_names = f'data_{idx}.csv'
    energy_lst = pd.read_csv(f'{log_dir}/{file_names}')
    energy_lst.rename(columns = {'#"Step"':'Step'}, inplace = True)
    energy_lst.rename(columns = {'Potential Energy (kJ/mole)': 'energy'}, inplace = True)
    return energy_lst

energy_step = read_energy_csv(log_dir, idx=3)

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(energy_step).transform_fold(['energy']).mark_line().encode(
    x='Step:Q',
    y='value:Q',
    color='key:N'
).interactive()
# Out:
# /opt/conda/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
energy_step
# Out:
#       Step      energy  Temperature (K)  Density (g/mL)
# 0        1  107.317600       106.191397        0.049042
# 1        2  100.744140       112.576467        0.049042
# 2        3   86.031346       142.149776        0.049042
# 3        4   68.078431       187.504268        0.049042
# 4        5   55.013442       229.362321        0.049042
# ...    ...         ...              ...             ...
# 4995  4996   42.947764       112.861347        0.049042
# 4996  4997   43.771702       111.989029        0.049042
# 4997  4998   45.496436       110.367023        0.049042
# 4998  4999   47.288834       105.330485        0.049042
# 4999  5000   47.723700       101.985495        0.049042
#
# [5000 rows x 4 columns]
